# %%
def function_name(arg1, arg2):
    pass

# %%
9/4
# Out:
# 2

# %%
def f_k(temperature):
    return((temperature - 32) * (5 / 9) + 273.15)

# %%
f_k(32)
# Out:
# 273.15

# %%
f_k(212)
# Out:
# 373.15

# %%
def f_k(temperature):
    return((temperature - 32) * (5 / 9.0) + 273.15)

# %%
f_k(32)
# Out:
# 273.15

# %%
f_k(212)
# Out:
# 373.15

# %%
def k_c(temp):
    return(temp - 273.15)

# %%
k_c(0)
# Out:
# -273.15

# %%
def f_c(temp):
    temp_k = f_k(temp)
    result = k_c(temp_k)
    return(result)

# %%
f_c(32)
# Out:
# 0.0

# %%
import numpy
import matplotlib.pyplot
import glob

# %matplotlib inline

def analyze_data(inflammation_file):
    data = numpy.loadtxt(fname=inflammation_file, delimiter=',')

    fig = matplotlib.pyplot.figure(figsize=(10.0, 3.0))

    axes1 = fig.add_subplot(1, 3, 1)
    axes2 = fig.add_subplot(1, 3, 2)
    axes3 = fig.add_subplot(1, 3, 3)

    axes1.set_ylabel('average')
    axes1.plot(data.mean(axis=0))

    axes2.set_ylabel('std')
    axes2.plot(data.std(axis=0))

    axes3.set_ylabel('max')
    axes3.plot(data.max(axis=0))

    fig.tight_layout()

    matplotlib.pyplot.show(fig)

# %%
inflammation_files = glob.glob('data/inflammation*')
print(inflammation_files)

for file in inflammation_files:
    analyze_data(file)
# Out:
# ['data/inflammation-07.csv', 'data/inflammation-02.csv', 'data/inflammation-09.csv', 'data/inflammation-05.csv', 'data/inflammation-04.csv', 'data/inflammation-12.csv', 'data/inflammation-03.csv', 'data/inflammation-06.csv', 'data/inflammation-08.csv', 'data/inflammation-10.csv', 'data/inflammation-01.csv', 'data/inflammation-11.csv']

# %%
print(f_c(32))
# Out:
# 0.0

# %%
print(f_c(212))
# Out:
# 100.0

# %%
print(f_k(212))
# Out:
# 373.15

# %%
assert f_k(212) == 373.15

# %%
assert f_k(32) == 273.15
